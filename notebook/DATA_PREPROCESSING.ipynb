# %%
import pandas as pd
import numpy as np
import warnings

from sklearn.experimental import enable_iterative_imputer

from sklearn.impute import SimpleImputer
from sklearn.impute import IterativeImputer

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler, OneHotEncoder

from sklearn.pipeline import Pipeline

from sdv.datasets.demo import download_demo

warnings.filterwarnings("ignore")

def preprocess_data(
		PATHS = ['../data/bank-full.csv', "../data/churn-modelling.csv"],
		SYNTHETIC = ['credit'],
		num_pipeline = Pipeline(steps=[("imputer", IterativeImputer(random_state=0)),]),
		cat_pipeline = Pipeline(steps=[("imputer", SimpleImputer(strategy="most_frequent")),]),
		label = 'subscribed'
	):

	df1 = pd.read_csv(PATHS[0])
	df2 = pd.read_csv(PATHS[1])
	real_data, metadata = download_demo(
		modality='single_table',
		dataset_name='insurance'
	) 

	# df1.rename({i:i.lower() for i in df2.columns.values}, axis=1, inplace=True)
	# df2.rename({i:i.lower() for i in df2.columns.values}, axis=1, inplace=True)

	#
	dtype_dict = pd.DataFrame(pd.concat([df1.dtypes, (df2.dtypes)], axis=0))
	dtype_dict = dtype_dict.T.loc[:, ~dtype_dict.T.columns.duplicated()].T.copy().iloc[:, 0]

	# Merge Dataframes
	merged_df = pd.concat([df1, df2], axis=0, ignore_index=True)

	# Find numerical & categorical columns
	which_object = [i == np.dtype('O') for i in merged_df.dtypes]
	categorical_columns = merged_df.columns[which_object].values
	numerical_columns = merged_df.columns[np.invert(which_object)].values
	all_columns = np.concatenate([numerical_columns, categorical_columns])

	# Rearrange column sequence
	merged_df = merged_df.loc[:, all_columns]
	merged_df.reset_index(drop=True)
	merged_df[categorical_columns] = merged_df.loc[:, categorical_columns].astype('category')
	
	# 
	cat_dtypes = dict(merged_df.dtypes[categorical_columns])
	num_dtypes = dict(dtype_dict[numerical_columns])
	# print(dict(num_dtypes))
	dtype_dict = num_dtypes | cat_dtypes

	preprocessor = ColumnTransformer(transformers=[
			("num_pipeline", num_pipeline, numerical_columns),
			("cat_pipeline", cat_pipeline, categorical_columns),
	])
	# Apply transformation on dataset
	processed_data = preprocessor.fit_transform(merged_df)

	# Convert processed_data back to a DataFrame
	processed_df = pd.DataFrame(processed_data, columns=all_columns)

	# Convert numerical columns back to float
	processed_df.loc[:, numerical_columns] = processed_df[numerical_columns].apply(pd.to_numeric)

	# processed_df.loc[:, numerical_columns].astype(num_dtypes)
	processed_df = processed_df.astype(dtype_dict)

	# feat_cols = [i for i in processed_df.columns if (i != 'subscribed' and i != 'exited' and i != 'customerid')]
	
	feat_cols = processed_df.columns.drop(['subscribed', 'exited', 'customerid', 'surname', 'isactivemember'])

	X = processed_df[feat_cols]
	y = processed_df[[label]]

	return X, y

X, y = preprocess_data()
# X.columns
X
# Out:
#        age    balance  day  duration  campaign  pdays  previous  creditscore  \
# 0       58    2143.00    5       261         1     -1         0          649
# 1       44      29.00    5       151         1     -1         0          649
# 2       33       2.00    5        76         1     -1         0          649
# 3       47    1506.00    5        92         1     -1         0          649
# 4       33       1.00    5       198         1     -1         0          649
# ...    ...        ...  ...       ...       ...    ...       ...          ...
# 55206   39       0.00   15       256         2     40         0          771
# 55207   35   57369.61   17       358         1     37         1          516
# 55208   36       0.00   15       256         2     41         0          709
# 55209   42   75075.31   17       388         1     35         1          772
# 55210   28  130142.79   19       488         0     34         1          792
#
#        tenure  numofproducts  ...  education default housing loan   contact  \
# 0           5              1  ...   tertiary      no     yes   no   unknown
# 1           5              1  ...  secondary      no     yes   no   unknown
# 2           5              1  ...  secondary      no     yes  yes   unknown
# 3           5              1  ...    unknown      no     yes   no   unknown
# 4           5              1  ...    unknown      no      no   no   unknown
# ...       ...            ...  ...        ...     ...     ...  ...       ...
# 55206       5              2  ...  secondary      no     yes   no  cellular
# 55207      10              1  ...  secondary      no     yes   no  cellular
# 55208       7              1  ...  secondary      no     yes   no  cellular
# 55209       3              2  ...  secondary      no     yes   no  cellular
# 55210       4              1  ...  secondary      no     yes   no  cellular
#
#       month poutcome geography  gender hascrcard
# 0       may  unknown    France    Male       yes
# 1       may  unknown    France    Male       yes
# 2       may  unknown    France    Male       yes
# 3       may  unknown    France    Male       yes
# 4       may  unknown    France    Male       yes
# ...     ...      ...       ...     ...       ...
# 55206   may  unknown    France    Male       yes
# 55207   may  unknown    France    Male       yes
# 55208   may  unknown    France  Female        no
# 55209   may  unknown   Germany    Male       yes
# 55210   may  unknown    France  Female       yes
#
# [55211 rows x 23 columns]

# %%
from sdv.datasets.demo import get_available_demos
get_available_demos(modality='single_table')
# Out:
#               dataset_name  size_MB  num_tables
# 0                   KRK_v1     0.06           1
# 1                    adult     3.91           1
# 2                    alarm     4.52           1
# 3                     asia     1.28           1
# 4                   census    98.17           1
# 5          census_extended     4.95           1
# 6                    child     3.20           1
# 7                  covtype   255.65           1
# 8                   credit    68.35           1
# 9       expedia_hotel_logs     0.20           1
# 10          fake_companies     0.00           1
# 11       fake_hotel_guests     0.03           1
# 12                    grid     0.32           1
# 13                   gridr     0.32           1
# 14               insurance     3.34           1
# 15               intrusion   162.04           1
# 16                 mnist12    81.20           1
# 17                 mnist28   439.60           1
# 18                    news    18.71           1
# 19                    ring     0.32           1
# 20      student_placements     0.03           1
# 21  student_placements_pii     0.03           1

# %%
from sdv.datasets.demo import download_demo
real_data, metadata = download_demo(
 	modality='single_table',
 	dataset_name='insurance'
)
print(real_data.head())
real_data.to_csv("../data/insurance.csv")
# metadata.visualize()
# Out:
#    GoodStudent         Age SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False  Adolescent    Middle       Normal     Current     Severe
# 1        False  Adolescent     Prole  Adventurous       Older     Severe
# 2         True  Adolescent     Prole     Cautious       Older        NaN
# 3        False       Adult    Middle     Cautious       Older        NaN
# 4        False  Adolescent     Prole  Adventurous     Current   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell  Moderate      Economy        Poor  ...   Suburb       True
# 1   EggShell    Severe      Economy        Poor  ...     City      False
# 2   EggShell       NaN      Economy      Normal  ...     City       True
# 3   Football       NaN  FamilySedan      Normal  ...   Suburb       True
# 4   Football  Moderate      Economy        Poor  ...     City      False
#
#       PropCost  OtherCarCost OtherCar      MedCost Cushioning Airbag  \
# 0  HundredThou      Thousand     True  HundredThou       Poor   True
# 1  HundredThou       TenThou     True      TenThou       Poor  False
# 2      TenThou      Thousand     True     Thousand       Poor  False
# 3     Thousand      Thousand     True     Thousand       Fair   True
# 4  HundredThou   HundredThou    False      TenThou  Excellent   True
#
#     ILiCost DrivHist
# 0  Thousand      One
# 1  Thousand     Many
# 2  Thousand     Zero
# 3  Thousand     Zero
# 4  Thousand     Many
#
# [5 rows x 27 columns]

# %%
from sdv.single_table import GaussianCopulaSynthesizer
synthesizer = GaussianCopulaSynthesizer(metadata)
synth = synthesizer.fit(real_data)
synthesizer.sample(num_rows=10)
# Out:
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole     Cautious     Current   Moderate
# 1        False       Adult        Prole       Normal       Older     Severe
# 2        False       Adult        Prole       Normal     Current        NaN
# 3        False       Adult        Prole       Normal       Older        NaN
# 4        False  Adolescent       Middle       Normal       Older   Moderate
# 5        False       Adult  UpperMiddle       Normal       Older        NaN
# 6        False      Senior       Middle       Normal       Older        NaN
# 7        False       Adult       Middle       Normal     Current     Severe
# 8        False       Adult  UpperMiddle       Normal       Older        NaN
# 9         True  Adolescent       Middle     Cautious       Older        NaN
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   Football       NaN  FamilySedan      Normal  ...   Secure      False
# 1   Football  Moderate  FamilySedan        Poor  ...     City       True
# 2   EggShell      Mild      Economy      Normal  ...   Suburb      False
# 3   Football  Moderate    SportsCar      Normal  ...     City       True
# 4   Football       NaN      Economy      Normal  ...   Suburb       True
# 5   EggShell       NaN    SportsCar        Poor  ...   Suburb      False
# 6   Football  Moderate      Economy      Normal  ...     City       True
# 7   Football  Moderate       Luxury        Poor  ...   Secure       True
# 8   Football       NaN      Economy        Poor  ...     City      False
# 9   Football       NaN  FamilySedan        Poor  ...     City       True
#
#       PropCost  OtherCarCost OtherCar   MedCost Cushioning Airbag   ILiCost  \
# 0     Thousand      Thousand     True  Thousand       Poor  False  Thousand
# 1     Thousand      Thousand     True  Thousand  Excellent  False  Thousand
# 2      TenThou      Thousand     True  Thousand       Poor  False  Thousand
# 3  HundredThou      Thousand    False  Thousand       Good   True  Thousand
# 4     Thousand      Thousand     True   Million  Excellent   True  Thousand
# 5     Thousand       TenThou    False  Thousand       Poor  False  Thousand
# 6  HundredThou      Thousand    False  Thousand  Excellent  False  Thousand
# 7     Thousand   HundredThou     True  Thousand  Excellent   True  Thousand
# 8     Thousand      Thousand     True  Thousand       Fair  False  Thousand
# 9     Thousand      Thousand     True  Thousand       Good   True  Thousand
#
#   DrivHist
# 0     Zero
# 1     Zero
# 2     Many
# 3      One
# 4     Zero
# 5      One
# 6     Zero
# 7     Zero
# 8     Zero
# 9     Zero
#
# [10 rows x 27 columns]
